# %% [markdown]
# <a href="https://colab.research.google.com/github/MdImran2021/DS_Days/blob/main/Day5_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("/content/Car.csv")

# %%
x= data.iloc[:,:1].values
y = data.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.25)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (603, 1)
# (603,)
# (201, 1)
# (201,)

# %%
print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
# [[26831.19404 ]
#  [12099.01458 ]
#  [30800.65839 ]
#  [17202.83406 ]
#  [11179.95357 ]
#  [39875.85426 ]
#  [21183.12359 ]
#  [17978.357   ]
#  [ 9482.219404]
#  [13436.00015 ]
#  [18543.42705 ]
#  [ 9563.789309]
#  [15802.65286 ]
#  [22311.04951 ]
#  [ 9919.048185]
#  [17360.81064 ]
#  [19567.25929 ]
#  [18273.00613 ]
#  [18254.92277 ]
#  [24852.49528 ]
#  [12209.55962 ]
#  [29986.7915  ]
#  [20698.07708 ]
#  [15118.89323 ]
#  [26841.08084 ]
#  [12333.60399 ]
#  [ 9220.829677]
#  [14771.00346 ]
#  [24405.06676 ]
#  [11302.90299 ]
#  [15623.91976 ]
#  [32197.34047 ]
#  [21725.01075 ]
#  [14077.96885 ]
#  [25618.28188 ]
#  [20537.14172 ]
#  [23420.70695 ]
#  [29142.71439 ]
#  [23197.43679 ]
#  [41671.58314 ]
#  [15797.19576 ]
#  [17808.199   ]
#  [30661.26015 ]
#  [15457.17059 ]
#  [40335.73731 ]
#  [16803.12275 ]
#  [17418.06873 ]
#  [11413.5304  ]
#  [19338.376   ]
#  [27060.13756 ]
#  [60567.54909 ]
#  [17119.45757 ]
#  [13699.03578 ]
#  [31554.40533 ]
#  [15568.97424 ]
# ...

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()

# %%
slr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = slr.predict(x_test)

# %%
y_pred
# Out:
# array([19709.0226767 , 18567.4752875 , 20944.80295016, 20474.3729316 ,
#        20221.24721036, 18891.36675334, 20786.76978126, 19721.41253821,
#        20970.695696  , 20909.42537899, 20455.77240388, 19752.48327383,
#        20558.90559356, 18219.79904764, 20489.12572409, 20701.65039814,
#        19914.29506245, 20112.90115146, 20483.02701133, 20367.29993926,
#        20189.27067595, 19452.00419692, 20538.97089331, 20606.56538448,
#        20055.36027801, 20828.07461357, 19576.35835177, 20750.01715351,
#        18717.5490153 , 18834.90500703, 19298.42947225, 19545.67136372,
#        20869.60283313, 20340.1683516 , 20931.20099756, 20477.18337461,
#        20575.13549845, 20526.60943233, 19726.1920185 , 19710.45323742,
#        19089.20446559, 19545.97634661, 19879.47886413, 20633.25573705,
#        17728.18871877, 19759.89544475, 20188.20823739, 20340.63806098,
#        19923.51853027, 19751.18945321, 20325.76340491, 21188.32603027,
# ...

# %%
x_test
# Out:
# array([[21908.36662 ],
#        [31969.06981 ],
#        [11017.16871 ],
#        [15163.16986 ],
#        [17394.0214  ],
#        [29114.54451 ],
#        [12409.94909 ],
#        [21799.1721  ],
#        [10788.97036 ],
#        [11328.95887 ],
#        [15327.10032 ],
#        [21525.33901 ],
#        [14418.16529 ],
#        [35033.21545 ],
#        [15033.15032 ],
#        [13160.12456 ],
#        [20099.25684 ],
#        [18348.89857 ],
#        [15086.89959 ],
#        [16106.82722 ],
#        [17675.83749 ],
#        [24173.52588 ],
#        [14593.8541  ],
#        [13998.12928 ],
#        [18856.01869 ],
#        [12045.9207  ],
#        [23077.56591 ],
#        [12733.85792 ],
#        [30646.4377  ],
#        [29612.15405 ],
#        [25527.01303 ],
#        [23348.01695 ],
#        [11679.92355 ],
#        [16345.94375 ],
#        [11137.04565 ],
#        [15138.40082 ],
#        [14275.12764 ],
#        [14702.79832 ],
#        [21757.04951 ],
#        [21895.75878 ],
# ...

# %%
plt.scatter(x_train,y_train, color = "blue")
plt.plot(x_train, slr.predict(x_train), color = "green")
plt.title("Simple Linear Regression Model")
plt.xlabel("Price")
plt.ylabel("Mileage")
plt.show()

# %%
plt.scatter(x_test,y_test, color = "blue")
plt.plot(x_test, slr.predict(x_test), color = "green")
plt.title("Simple Linear Regression Model")
plt.xlabel("Price")
plt.ylabel("Mileage")
plt.show()
